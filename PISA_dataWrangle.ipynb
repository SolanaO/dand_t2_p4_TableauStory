# %% [markdown]
# # PISA Data Description and Wrangling

# %% [markdown]
# ## Overview
#
# PISA is a survey of students' skills and knowledge as they approach the end of compulsory education. It is not a conventional school test. Rather than examining how well students have learned the school curriculum, it looks at how well prepared they are for life beyond school.
#
# Around 510,000 students in 65 economies took part in the PISA 2012 assessment of reading, mathematics and science representing about 28 million 15-year-olds globally. Of those economies, 44 took part in an assessment of creative problem solving and 18 in an assessment of financial literacy. For more details see [PISA website](https://www.oecd.org/pisa/pisaproducts/datavisualizationcontest.htm).
#
# The data and topics of investigation come from the PISA Data Visualization Competition.

# %% [markdown]
# #### Topics suggested by Udacity:
#
# 1. The importance of school factors in explaining academic performance.
#
# 2. **Differences in achievement based on gender, location, or student attitudes.**
#
# 3. Differences in achievement based on teacher practices and attitudes.
#
# 4. Inequalities in academic achievement.

# %% [markdown]
# ## Data wrangling

# %% [markdown]
# In this report the PISA 2012 will be used to investigate the differences in achievement in mathematics tests based on location, gender and student attitudes. Keeping these tasks in mind, the data wrangling will proceed as follows:
#
# 1. Download the two datafiles 'pisadict2012.csv' (which contains the description of all codes and abbreviations in the main table) and 'pisa2012.csv' (the main datafile, the unzipped csv file is 2.75 GB).
#
# 2. Wrangle the dictionary of terms file, keep only those columns that are relevant to this analysis.
#
# 3. Use sqlalchemy to extract a managable size Pandas dataframe from the main PISA data file, this is done using tthe methods described in [Working with large csv files in Python](https://pythondata.com/working-large-csv-files-python/).
#
# 4. Clean some minor issues regarding the countries involved in the study.

# %%
### import the necessary packages to work with the datasets  
import numpy as np
import pandas as pd

from sqlalchemy import create_engine

# %%
### option to display full content of columns in the dataframes
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ### The dictionary of terms datafile

# %%
### save the dictionary of terms as pandas dataframe
df_dict=pd.read_csv("pisadict2012.csv", encoding='iso-8859-1')

# %%
### investigate the dataframe
df_dict.sample(4)
# Out:
#     Unnamed: 0                                                  x
# 585  W_FSTR35   FINAL STUDENT REPLICATE BRR-FAY WEIGHT35
# 442  HOSTCUL    Acculturation: Host Culture Oriented Strategies
# 551  W_FSTR1    FINAL STUDENT REPLICATE BRR-FAY WEIGHT1
# 254  ST89Q05    Attitude toward School - Trying Hard is Important

# %%
### rename the columns
df_dict.columns = ['Code', 'Description']

# %%
### get more information about the dataframe
df_dict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 635 entries, 0 to 634
# Data columns (total 2 columns):
# Code           635 non-null object
# Description    635 non-null object
# dtypes: object(2)
# memory usage: 10.0+ KB

# %% [markdown]
# #### Downsizing the list of columns to be used in the analysis:
# 1. Investigate the available codes in the list, there are several categories of such codes: abbreviations, ST#, IC#, EC#, PV# and W_FSTR#.
# 2. Look at ST# codes, identification codes from the beginning of the dataframe, and codes that contain the work mathematics (or versions of it) in description.
# 3. ST codes are divided on categories, keep some of ST3 and all ST4 and ST9 entries.
# 4. Manually select the codes that make reference to mathematics in description.

# %%
df_dict.head(20);

# %%
### the codes that contain information about the student
df1 = df_dict.iloc[[0, 1, 2, 3, 6, 7, 11], :]
df1
# Out:
#         Code  \
# 0   CNT
# 1   SUBNATIO
# 2   STRATUM
# 3   OECD
# 6   STIDSTD
# 7   ST01Q01
# 11  ST04Q01
#
#                                                                                  Description
# 0   Country code 3-character
# 1   Adjudicated sub-region code 7-digit code (3-digit country code + region ID + stratum ID)
# 2   Stratum ID 7-character (cnt + region ID + original stratum ID)
# 3   OECD country
# 6   Student ID
# 7   International Grade
# 11  Gender

# %%
### investigate the ST0# codes and extract them in a separate dataframe
df_st0=df_dict[df_dict['Code'].str.contains('ST0')]
df_st0
# Out:
#        Code                      Description
# 7   ST01Q01  International Grade
# 8   ST02Q01  National Study Programme
# 9   ST03Q01  Birth - Month
# 10  ST03Q02  Birth -Year
# 11  ST04Q01  Gender
# 12  ST05Q01  Attend <ISCED 0>
# 13  ST06Q01  Age at <ISCED 1>
# 14  ST07Q01  Repeat - <ISCED 1>
# 15  ST07Q02  Repeat - <ISCED 2>
# 16  ST07Q03  Repeat - <ISCED 3>
# 17  ST08Q01  Truancy - Late for School
# 18  ST09Q01  Truancy - Skip whole school day

# %%
### investigate the ST1# codes and extract them in a separate dataframe
df_st1=df_dict[df_dict['Code'].str.contains('ST1')]
df_st1
# Out:
#          Code                                    Description
# 19   ST115Q01  Truancy - Skip classes within school day
# 20   ST11Q01   At Home - Mother
# 21   ST11Q02   At Home - Father
# 22   ST11Q03   At Home - Brothers
# 23   ST11Q04   At Home - Sisters
# 24   ST11Q05   At Home - Grandparents
# 25   ST11Q06   At Home - Others
# 26   ST13Q01   Mother<Highest Schooling>
# 27   ST14Q01   Mother Qualifications - <ISCED level 6>
# 28   ST14Q02   Mother Qualifications - <ISCED level 5A>
# 29   ST14Q03   Mother Qualifications - <ISCED level 5B>
# 30   ST14Q04   Mother Qualifications - <ISCED level 4>
# 31   ST15Q01   Mother Current Job Status
# 32   ST17Q01   Father<Highest Schooling>
# 33   ST18Q01   Father Qualifications - <ISCED level 6>
# 34   ST18Q02   Father Qualifications - <ISCED level 5A>
# 35   ST18Q03   Father Qualifications - <ISCED level 5B>
# 36   ST18Q04   Father Qualifications - <ISCED level 4>
# 37   ST19Q01   Father Current Job Status
# 275  ST101Q01  Problem Route Selection - Read brochure
# 276  ST101Q02  Problem Route Selection - Study map
# 277  ST101Q03  Problem Route Selection - Leave it to brother
# 278  ST101Q05  Problem Route Selection - Just drive
# 279  ST104Q01  Problem Ticket Machine - Similarities
# 280  ST104Q04  Problem Ticket Machine - Try buttons
# 281  ST104Q05  Problem Ticket Machine - Ask for help
# 282  ST104Q06  Problem Ticket Machine - Find ticket office

# %%
### investigate the ST2# codes and extract them in a separate dataframe
df_st2=df_dict[df_dict['Code'].str.contains('ST2')]
df_st2
# Out:
#         Code  \
# 38   ST20Q01
# 39   ST20Q02
# 40   ST20Q03
# 41   ST21Q01
# 42   ST25Q01
# 43   ST26Q01
# 44   ST26Q02
# 45   ST26Q03
# 46   ST26Q04
# 47   ST26Q05
# 48   ST26Q06
# 49   ST26Q07
# 50   ST26Q08
# 51   ST26Q09
# 52   ST26Q10
# 53   ST26Q11
# 54   ST26Q12
# 55   ST26Q13
# 56   ST26Q14
# 57   ST26Q15
# 58   ST26Q16
# 59   ST26Q17
# 60   ST27Q01
# 61   ST27Q02
# 62   ST27Q03
# 63   ST27Q04
# 64   ST27Q05
# 65   ST28Q01
# 66   ST29Q01
# 67   ST29Q02
# 68   ST29Q03
# 69   ST29Q04
# 70   ST29Q05
# 71   ST29Q06
# 72   ST29Q07
# 73   ST29Q08
# 391  ST22Q01
# 392  ST23Q01
# 393  ST23Q02
# 394  ST23Q03
# 395  ST23Q04
# 396  ST23Q05
# 397  ST23Q06
# 398  ST23Q07
# 399  ST23Q08
# 400  ST24Q01
# 401  ST24Q02
# 402  ST24Q03
#
#                                                                           Description
# 38   Country of Birth International - Self
# 39   Country of Birth International - Mother
# 40   Country of Birth International - Father
# 41   Age of arrival in <country of test>
# 42   International Language at Home
# 43   Possessions - desk
# 44   Possessions - own room
# 45   Possessions - study place
# 46   Possessions - computer
# 47   Possessions - software
# 48   Possessions - Internet
# 49   Possessions - literature
# 50   Possessions - poetry
# 51   Possessions - art
# 52   Possessions - textbooks
# 53   Possessions - <technical reference books>
# 54   Possessions - dictionary
# 55   Possessions - dishwasher
# 56   Possessions - <DVD>
# 57   Possessions - <Country item 1>
# 58   Possessions - <Country item 2>
# 59   Possessions - <Country item 3>
# 60   How many - cellular phones
# 61   How many - televisions
# 62   How many - computers
# 63   How many - cars
# 64   How many - rooms bath or shower
# 65   How many books at home
# 66   Math Interest - Enjoy Reading
# 67   Instrumental Motivation - Worthwhile for Work
# 68   Math Interest - Look Forward to Lessons
# 69   Math Interest - Enjoy Maths
# 70   Instrumental Motivation - Worthwhile for Career Chances
# 71   Math Interest - Interested
# 72   Instrumental Motivation - Important for Future Study
# 73   Instrumental Motivation - Helps to Get a Job
# 391  Acculturation - Mother Immigrant (Filter)
# 392  Acculturation - Enjoy <Host Culture> Friends
# 393  Acculturation - Enjoy <Heritage Culture> Friends
# 394  Acculturation - Enjoy <Host Culture> Celebrations
# 395  Acculturation - Enjoy <Heritage Culture> Celebrations
# 396  Acculturation - Spend Time with <Host Culture> Friends
# 397  Acculturation - Spend Time with <Heritage Culture> Friends
# 398  Acculturation - Participate in <Host Culture> Celebrations
# 399  Acculturation - Participate in <Heritage Culture> Celebrations
# 400  Acculturation - Perceived Host-Heritage Cultural Differences - Values
# 401  Acculturation - Perceived Host-Heritage Cultural Differences - Mother Treatment
# 402  Acculturation - Perceived Host-Heritage Cultural Differences - Teacher Treatment

# %%
### investigate the ST3# codes and extract them in a separate dataframe
df_st3_all=df_dict[df_dict['Code'].str.contains('ST3')]
df_st3_all
# Out:
#        Code  \
# 74  ST35Q01
# 75  ST35Q02
# 76  ST35Q03
# 77  ST35Q04
# 78  ST35Q05
# 79  ST35Q06
# 80  ST37Q01
# 81  ST37Q02
# 82  ST37Q03
# 83  ST37Q04
# 84  ST37Q05
# 85  ST37Q06
# 86  ST37Q07
# 87  ST37Q08
#
#                                                                Description
# 74  Subjective Norms -Friends Do Well in Mathematics
# 75  Subjective Norms -Friends Work Hard on Mathematics
# 76  Subjective Norms - Friends Enjoy Mathematics Tests
# 77  Subjective Norms - Parents Believe Studying Mathematics Is Important
# 78  Subjective Norms - Parents Believe Mathematics Is Important for Career
# 79  Subjective Norms - Parents Like Mathematics
# 80  Math Self-Efficacy - Using a <Train Timetable>
# 81  Math Self-Efficacy - Calculating TV Discount
# 82  Math Self-Efficacy - Calculating Square Metres of Tiles
# 83  Math Self-Efficacy - Understanding Graphs in Newspapers
# 84  Math Self-Efficacy - Solving Equation 1
# 85  Math Self-Efficacy - Distance to Scale
# 86  Math Self-Efficacy - Solving Equation 2
# 87  Math Self-Efficacy - Calculate Petrol Consumption Rate

# %%
### only the first six ST3# codes are relevant for this study
### extract them in a separate dataframe
df_st3 = df_st3_all.iloc[0:6, :]
df_st3
# Out:
#        Code  \
# 74  ST35Q01
# 75  ST35Q02
# 76  ST35Q03
# 77  ST35Q04
# 78  ST35Q05
# 79  ST35Q06
#
#                                                                Description
# 74  Subjective Norms -Friends Do Well in Mathematics
# 75  Subjective Norms -Friends Work Hard on Mathematics
# 76  Subjective Norms - Friends Enjoy Mathematics Tests
# 77  Subjective Norms - Parents Believe Studying Mathematics Is Important
# 78  Subjective Norms - Parents Believe Mathematics Is Important for Career
# 79  Subjective Norms - Parents Like Mathematics

# %%
### investigate the ST4# codes and extract them in a separate dataframe
df_st4=df_dict[df_dict['Code'].str.contains('ST4')]
df_st4
# Out:
#         Code  \
# 88   ST42Q01
# 89   ST42Q02
# 90   ST42Q03
# 91   ST42Q04
# 92   ST42Q05
# 93   ST42Q06
# 94   ST42Q07
# 95   ST42Q08
# 96   ST42Q09
# 97   ST42Q10
# 98   ST43Q01
# 99   ST43Q02
# 100  ST43Q03
# 101  ST43Q04
# 102  ST43Q05
# 103  ST43Q06
# 104  ST44Q01
# 105  ST44Q03
# 106  ST44Q04
# 107  ST44Q05
# 108  ST44Q07
# 109  ST44Q08
# 110  ST46Q01
# 111  ST46Q02
# 112  ST46Q03
# 113  ST46Q04
# 114  ST46Q05
# 115  ST46Q06
# 116  ST46Q07
# 117  ST46Q08
# 118  ST46Q09
# 119  ST48Q01
# 120  ST48Q02
# 121  ST48Q03
# 122  ST48Q04
# 123  ST48Q05
# 124  ST49Q01
# 125  ST49Q02
# 126  ST49Q03
# 127  ST49Q04
# 128  ST49Q05
# 129  ST49Q06
# 130  ST49Q07
# 131  ST49Q09
#
#                                                                    Description
# 88   Math Anxiety - Worry That It Will Be Difficult
# 89   Math Self-Concept - Not Good at Maths
# 90   Math Anxiety - Get Very Tense
# 91   Math Self-Concept- Get Good <Grades>
# 92   Math Anxiety - Get Very Nervous
# 93   Math Self-Concept - Learn Quickly
# 94   Math Self-Concept - One of Best Subjects
# 95   Math Anxiety - Feel Helpless
# 96   Math Self-Concept - Understand Difficult Work
# 97   Math Anxiety - Worry About Getting Poor <Grades>
# 98   Perceived Control - Can Succeed with Enough Effort
# 99   Perceived Control - Doing Well is Completely Up to Me
# 100  Perceived Control - Family Demands and Problems
# 101  Perceived Control - Different Teachers
# 102  Perceived Control - If I Wanted I Could Perform Well
# 103  Perceived Control - Perform Poorly Regardless
# 104  Attributions to Failure - Not Good at Maths Problems
# 105  Attributions to Failure - Teacher Did Not Explain Well
# 106  Attributions to Failure - Bad Guesses
# 107  Attributions to Failure - Material Too Hard
# 108  Attributions to Failure - Teacher Didnt Get Students Interested
# 109  Attributions to Failure - Unlucky
# 110  Math Work Ethic - Homework Completed in Time
# 111  Math Work Ethic - Work Hard on Homework
# 112  Math Work Ethic - Prepared for Exams
# 113  Math Work Ethic - Study Hard for Quizzes
# 114  Math Work Ethic - Study Until I Understand Everything
# 115  Math Work Ethic - Pay Attention in Classes
# 116  Math Work Ethic - Listen in Classes
# 117  Math Work Ethic - Avoid Distractions When Studying
# 118  Math Work Ethic - Keep Work Organized
# 119  Math Intentions - Mathematics vs. Language Courses After School
# 120  Math Intentions - Mathematics vs. Science Related Major in College
# 121  Math Intentions - Study Harder in Mathematics vs. Language Classes
# 122  Math Intentions - Take Maximum Number of Mathematics vs. Science Classes
# 123  Math Intentions - Pursuing a Career That Involves Mathematics vs. Science
# 124  Math Behaviour - Talk about Maths with Friends
# 125  Math Behaviour - Help Friends with Maths
# 126  Math Behaviour - <Extracurricular> Activity
# 127  Math Behaviour - Participate in Competitions
# 128  Math Behaviour - Study More Than 2 Extra Hours a Day
# 129  Math Behaviour - Play Chess
# 130  Math Behaviour - Computer programming
# 131  Math Behaviour - Participate in Math Club

# %%
### investigate the ST5# codes and extract them in a separate dataframe
df_st5=df_dict[df_dict['Code'].str.contains('ST5')]
df_st5
# Out:
#         Code  \
# 132  ST53Q01
# 133  ST53Q02
# 134  ST53Q03
# 135  ST53Q04
# 136  ST55Q01
# 137  ST55Q02
# 138  ST55Q03
# 139  ST55Q04
# 140  ST57Q01
# 141  ST57Q02
# 142  ST57Q03
# 143  ST57Q04
# 144  ST57Q05
# 145  ST57Q06
#
#                                                                               Description
# 132  Learning Strategies- Important Parts vs. Existing Knowledge vs. Learn by Heart
# 133  Learning Strategies- Improve Understanding vs. New Ways vs. Memory
# 134  Learning Strategies - Other Subjects vs. Learning Goals vs. Rehearse Problems
# 135  Learning Strategies - Repeat Examples vs. Everyday Applications vs. More Information
# 136  Out of school lessons - <test lang>
# 137  Out of school lessons - <maths>
# 138  Out of school lessons - <science>
# 139  Out of school lessons - other
# 140  Out-of-School Study Time - Homework
# 141  Out-of-School Study Time - Guided Homework
# 142  Out-of-School Study Time - Personal Tutor
# 143  Out-of-School Study Time - Commercial Company
# 144  Out-of-School Study Time - With Parent
# 145  Out-of-School Study Time - Computer

# %%
### investigate the ST6# codes and extract them in a separate dataframe
df_st6=df_dict[df_dict['Code'].str.contains('ST6')]
df_st6
# Out:
#         Code  \
# 146  ST61Q01
# 147  ST61Q02
# 148  ST61Q03
# 149  ST61Q04
# 150  ST61Q05
# 151  ST61Q06
# 152  ST61Q07
# 153  ST61Q08
# 154  ST61Q09
# 155  ST62Q01
# 156  ST62Q02
# 157  ST62Q03
# 158  ST62Q04
# 159  ST62Q06
# 160  ST62Q07
# 161  ST62Q08
# 162  ST62Q09
# 163  ST62Q10
# 164  ST62Q11
# 165  ST62Q12
# 166  ST62Q13
# 167  ST62Q15
# 168  ST62Q16
# 169  ST62Q17
# 170  ST62Q19
# 171  ST69Q01
# 172  ST69Q02
# 173  ST69Q03
#
#                                                                 Description
# 146  Experience with Applied Maths Tasks - Use <Train Timetable>
# 147  Experience with Applied Maths Tasks - Calculate Price including Tax
# 148  Experience with Applied Maths Tasks - Calculate Square Metres
# 149  Experience with Applied Maths Tasks - Understand Scientific Tables
# 150  Experience with Pure Maths Tasks - Solve Equation 1
# 151  Experience with Applied Maths Tasks - Use a Map to Calculate Distance
# 152  Experience with Pure Maths Tasks - Solve Equation 2
# 153  Experience with Applied Maths Tasks - Calculate Power Consumption Rate
# 154  Experience with Applied Maths Tasks - Solve Equation 3
# 155  Familiarity with Math Concepts - Exponential Function
# 156  Familiarity with Math Concepts - Divisor
# 157  Familiarity with Math Concepts - Quadratic Function
# 158  Overclaiming - Proper Number
# 159  Familiarity with Math Concepts - Linear Equation
# 160  Familiarity with Math Concepts - Vectors
# 161  Familiarity with Math Concepts - Complex Number
# 162  Familiarity with Math Concepts - Rational Number
# 163  Familiarity with Math Concepts - Radicals
# 164  Overclaiming - Subjunctive Scaling
# 165  Familiarity with Math Concepts - Polygon
# 166  Overclaiming - Declarative Fraction
# 167  Familiarity with Math Concepts - Congruent Figure
# 168  Familiarity with Math Concepts - Cosine
# 169  Familiarity with Math Concepts - Arithmetic Mean
# 170  Familiarity with Math Concepts - Probability
# 171  Min in <class period> - <test lang>
# 172  Min in <class period> - <Maths>
# 173  Min in <class period> - <Science>

# %%
### investigate the ST7# codes and extract them in a separate dataframe
df_st7=df_dict[df_dict['Code'].str.contains('ST7')]
df_st7
# Out:
#         Code  \
# 174  ST70Q01
# 175  ST70Q02
# 176  ST70Q03
# 177  ST71Q01
# 178  ST72Q01
# 179  ST73Q01
# 180  ST73Q02
# 181  ST74Q01
# 182  ST74Q02
# 183  ST75Q01
# 184  ST75Q02
# 185  ST76Q01
# 186  ST76Q02
# 187  ST77Q01
# 188  ST77Q02
# 189  ST77Q04
# 190  ST77Q05
# 191  ST77Q06
# 192  ST79Q01
# 193  ST79Q02
# 194  ST79Q03
# 195  ST79Q04
# 196  ST79Q05
# 197  ST79Q06
# 198  ST79Q07
# 199  ST79Q08
# 200  ST79Q10
# 201  ST79Q11
# 202  ST79Q12
# 203  ST79Q15
# 204  ST79Q17
#
#                                                                  Description
# 174  No of <class period> p/wk - <test lang>
# 175  No of <class period> p/wk - <Maths>
# 176  No of <class period> p/wk - <Science>
# 177  No of ALL <class period> a week
# 178  Class Size - No of Students in <Test Language> Class
# 179  OTL - Algebraic Word Problem in Math Lesson
# 180  OTL - Algebraic Word Problem in Tests
# 181  OTL - Procedural Task in Math Lesson
# 182  OTL - Procedural Task in Tests
# 183  OTL - Pure Math Reasoning in Math Lesson
# 184  OTL - Pure Math Reasoning in Tests
# 185  OTL - Applied Math Reasoning in Math Lesson
# 186  OTL - Applied Math Reasoning in Tests
# 187  Math Teaching - Teacher shows interest
# 188  Math Teaching - Extra help
# 189  Math Teaching - Teacher helps
# 190  Math Teaching - Teacher continues
# 191  Math Teaching - Express opinions
# 192  Teacher-Directed Instruction - Sets Clear Goals
# 193  Teacher-Directed Instruction - Encourages Thinking and Reasoning
# 194  Student Orientation - Differentiates Between Students When Giving Tasks
# 195  Student Orientation - Assigns Complex Projects
# 196  Formative Assessment - Gives Feedback
# 197  Teacher-Directed Instruction - Checks Understanding
# 198  Student Orientation - Has Students Work in Small Groups
# 199  Teacher-Directed Instruction - Summarizes Previous Lessons
# 200  Student Orientation - Plans Classroom Activities
# 201  Formative Assessment - Gives Feedback on Strengths and Weaknesses
# 202  Formative Assessment - Informs about Expectations
# 203  Teacher-Directed Instruction - Informs about Learning Goals
# 204  Formative Assessment - Tells How to Get Better

# %%
### investigate the ST8# codes and extract them in a separate dataframe
df_st8=df_dict[df_dict['Code'].str.contains('ST8')]
df_st8
# Out:
#         Code  \
# 205  ST80Q01
# 206  ST80Q04
# 207  ST80Q05
# 208  ST80Q06
# 209  ST80Q07
# 210  ST80Q08
# 211  ST80Q09
# 212  ST80Q10
# 213  ST80Q11
# 214  ST81Q01
# 215  ST81Q02
# 216  ST81Q03
# 217  ST81Q04
# 218  ST81Q05
# 219  ST82Q01
# 220  ST82Q02
# 221  ST82Q03
# 222  ST83Q01
# 223  ST83Q02
# 224  ST83Q03
# 225  ST83Q04
# 226  ST84Q01
# 227  ST84Q02
# 228  ST84Q03
# 229  ST85Q01
# 230  ST85Q02
# 231  ST85Q03
# 232  ST85Q04
# 233  ST86Q01
# 234  ST86Q02
# 235  ST86Q03
# 236  ST86Q04
# 237  ST86Q05
# 238  ST87Q01
# 239  ST87Q02
# 240  ST87Q03
# 241  ST87Q04
# 242  ST87Q05
# 243  ST87Q06
# 244  ST87Q07
# 245  ST87Q08
# 246  ST87Q09
# 247  ST88Q01
# 248  ST88Q02
# 249  ST88Q03
# 250  ST88Q04
# 251  ST89Q02
# 252  ST89Q03
# 253  ST89Q04
# 254  ST89Q05
#
#                                                                              Description
# 205  Cognitive Activation - Teacher Encourages to Reflect Problems
# 206  Cognitive Activation - Gives Problems that Require to Think
# 207  Cognitive Activation - Asks to Use Own Procedures
# 208  Cognitive Activation - Presents Problems with No Obvious Solutions
# 209  Cognitive Activation - Presents Problems in Different Contexts
# 210  Cognitive Activation - Helps Learn from Mistakes
# 211  Cognitive Activation - Asks for Explanations
# 212  Cognitive Activation - Apply What We Learned
# 213  Cognitive Activation - Problems with Multiple Solutions
# 214  Disciplinary Climate - Students Dont Listen
# 215  Disciplinary Climate - Noise and Disorder
# 216  Disciplinary Climate - Teacher Has to Wait Until its Quiet
# 217  Disciplinary Climate - Students Dont Work Well
# 218  Disciplinary Climate - Students Start Working Late
# 219  Vignette Teacher Support -Homework Every Other Day/Back in Time
# 220  Vignette Teacher Support - Homework Once a Week/Back in Time
# 221  Vignette Teacher Support - Homework Once a Week/Not Back in Time
# 222  Teacher Support - Lets Us Know We Have to Work Hard
# 223  Teacher Support - Provides Extra Help When Needed
# 224  Teacher Support - Helps Students with Learning
# 225  Teacher Support - Gives Opportunity to Express Opinions
# 226  Vignette Classroom Management - Students Frequently Interrupt/Teacher Arrives Early
# 227  Vignette Classroom Management - Students Are Calm/Teacher Arrives on Time
# 228  Vignette Classroom Management - Students Frequently Interrupt/Teacher Arrives Late
# 229  Classroom Management - Students Listen
# 230  Classroom Management - Teacher Keeps Class Orderly
# 231  Classroom Management - Teacher Starts On Time
# 232  Classroom Management - Wait Long to <Quiet Down>
# 233  Student-Teacher Relation - Get Along with Teachers
# 234  Student-Teacher Relation - Teachers Are Interested
# 235  Student-Teacher Relation - Teachers Listen to Students
# 236  Student-Teacher Relation - Teachers Help Students
# 237  Student-Teacher Relation - Teachers Treat Students Fair
# 238  Sense of Belonging - Feel Like Outsider
# 239  Sense of Belonging - Make Friends Easily
# 240  Sense of Belonging - Belong at School
# 241  Sense of Belonging - Feel Awkward at School
# 242  Sense of Belonging - Liked by Other Students
# 243  Sense of Belonging - Feel Lonely at School
# 244  Sense of Belonging - Feel Happy at School
# 245  Sense of Belonging - Things Are Ideal at School
# 246  Sense of Belonging - Satisfied at School
# 247  Attitude towards School - Does Little to Prepare Me for Life
# 248  Attitude towards School - Waste of Time
# 249  Attitude towards School - Gave Me Confidence
# 250  Attitude towards School- Useful for Job
# 251  Attitude toward School - Helps to Get a Job
# 252  Attitude toward School - Prepare for College
# 253  Attitude toward School - Enjoy Good Grades
# 254  Attitude toward School - Trying Hard is Important

# %%
### investigate the ST9# codes and extract them in a separate dataframe
df_st9=df_dict[df_dict['Code'].str.contains('ST9')]
df_st9
# Out:
#         Code  \
# 255  ST91Q01
# 256  ST91Q02
# 257  ST91Q03
# 258  ST91Q04
# 259  ST91Q05
# 260  ST91Q06
# 261  ST93Q01
# 262  ST93Q03
# 263  ST93Q04
# 264  ST93Q06
# 265  ST93Q07
# 266  ST94Q05
# 267  ST94Q06
# 268  ST94Q09
# 269  ST94Q10
# 270  ST94Q14
# 271  ST96Q01
# 272  ST96Q02
# 273  ST96Q03
# 274  ST96Q05
#
#                                                               Description
# 255  Perceived Control - Can Succeed with Enough Effort
# 256  Perceived Control - My Choice Whether I Will Be Good
# 257  Perceived Control - Problems Prevent from Putting Effort into School
# 258  Perceived Control - Different Teachers Would Make Me Try Harder
# 259  Perceived Control - Could Perform Well if I Wanted
# 260  Perceived Control - Perform Poor Regardless
# 261  Perseverance - Give up easily
# 262  Perseverance - Put off difficult problems
# 263  Perseverance - Remain interested
# 264  Perseverance - Continue to perfection
# 265  Perseverance - Exceed expectations
# 266  Openness for Problem Solving - Can Handle a Lot of Information
# 267  Openness for Problem Solving - Quick to Understand
# 268  Openness for Problem Solving - Seek Explanations
# 269  Openness for Problem Solving - Can Link Facts
# 270  Openness for Problem Solving - Like to Solve Complex Problems
# 271  Problem Text Message - Press every button
# 272  Problem Text Message - Trace steps
# 273  Problem Text Message - Manual
# 274  Problem Text Message - Ask a friend

# %%
### create a list of codes that contain the word M(m)athematic(s) in their description
### and are not in the ST# category

df_math = df_dict[(df_dict['Description'].str.contains('athematic'))
                 & (~df_dict['Code'].str.contains('ST3'))
                 & (~df_dict['Code'].str.contains('ST4'))]
df_math
# Out:
#             Code  \
# 413  ANXMAT
# 419  CLSMAN
# 423  COGACT
# 429  EXAPPLM
# 430  EXPUREM
# 431  FAILMAT
# 432  FAMCON
# 433  FAMCONC
# 452  INSTMOT
# 453  INTMAT
# 461  MATBEH
# 462  MATHEFF
# 463  MATINTFC
# 464  MATWKETH
# 466  MMINS
# 467  MTSUP
# 475  SCMAT
# 478  SUBNORM
# 485  USEMATH
# 491  ANCCLSMAN
# 492  ANCCOGACT
# 493  ANCINSTMOT
# 494  ANCINTMAT
# 495  ANCMATWKETH
# 496  ANCMTSUP
# 497  ANCSCMAT
# 499  ANCSUBNORM
# 500  PV1MATH
# 501  PV2MATH
# 502  PV3MATH
# 503  PV4MATH
# 504  PV5MATH
#
#                                                              Description
# 413  Mathematics Anxiety
# 419  Mathematics Teacher's Classroom Management
# 423  Cognitive Activation in Mathematics Lessons
# 429  Experience with Applied Mathematics Tasks at School
# 430  Experience with Pure Mathematics Tasks at School
# 431  Attributions to Failure in Mathematics
# 432  Familiarity with Mathematical Concepts
# 433  Familiarity with Mathematical Concepts (Signal Detection  Adjusted)
# 452  Instrumental Motivation for Mathematics
# 453  Mathematics Interest
# 461  Mathematics Behaviour
# 462  Mathematics Self-Efficacy
# 463  Mathematics Intentions
# 464  Mathematics Work Ethic
# 466  Learning time (minutes per week)- <Mathematics>
# 467  Mathematics Teacher's Support
# 475  Mathematics Self-Concept
# 478  Subjective Norms in Mathematics
# 485  Use of ICT in Mathematic Lessons
# 491  Mathematics Teacher's Classroom Management (Anchored)
# 492  Cognitive Activation in Mathematics Lessons (Anchored)
# 493  Instrumental Motivation for Mathematics (Anchored)
# 494  Mathematics Interest (Anchored)
# 495  Mathematics Work Ethic (Anchored)
# 496  Mathematics Teacher's Support (Anchored)
# 497  Mathematics Self-Concept (Anchored)
# 499  Subjective Norms in Mathematics (Anchored)
# 500  Plausible value 1 in mathematics
# 501  Plausible value 2 in mathematics
# 502  Plausible value 3 in mathematics
# 503  Plausible value 4 in mathematics
# 504  Plausible value 5 in mathematics

# %%
### create a list of codes that contains reference to math 
df_math_mat = df_math[(df_math['Code'].str.contains('MAT'))
                     & (~df_math['Code'].str.contains('ANC'))]
df_math_mat
# Out:
#          Code                             Description
# 413  ANXMAT    Mathematics Anxiety
# 431  FAILMAT   Attributions to Failure in Mathematics
# 453  INTMAT    Mathematics Interest
# 461  MATBEH    Mathematics Behaviour
# 462  MATHEFF   Mathematics Self-Efficacy
# 463  MATINTFC  Mathematics Intentions
# 464  MATWKETH  Mathematics Work Ethic
# 475  SCMAT     Mathematics Self-Concept
# 485  USEMATH   Use of ICT in Mathematic Lessons
# 500  PV1MATH   Plausible value 1 in mathematics
# 501  PV2MATH   Plausible value 2 in mathematics
# 502  PV3MATH   Plausible value 3 in mathematics
# 503  PV4MATH   Plausible value 4 in mathematics
# 504  PV5MATH   Plausible value 5 in mathematics

# %%
### use the previous steps to create a dataframe 
### that contains the list of column names to be extracted from the main datafile
df_dict_clean=pd.concat([df1, df_st3, df_st4, df_st9, df_math_mat])
df_dict_clean
# Out:
#          Code  \
# 0    CNT
# 1    SUBNATIO
# 2    STRATUM
# 3    OECD
# 6    STIDSTD
# 7    ST01Q01
# 11   ST04Q01
# 74   ST35Q01
# 75   ST35Q02
# 76   ST35Q03
# 77   ST35Q04
# 78   ST35Q05
# 79   ST35Q06
# 88   ST42Q01
# 89   ST42Q02
# 90   ST42Q03
# 91   ST42Q04
# 92   ST42Q05
# 93   ST42Q06
# 94   ST42Q07
# 95   ST42Q08
# 96   ST42Q09
# 97   ST42Q10
# 98   ST43Q01
# 99   ST43Q02
# 100  ST43Q03
# 101  ST43Q04
# 102  ST43Q05
# 103  ST43Q06
# 104  ST44Q01
# ..       ...
# 259  ST91Q05
# 260  ST91Q06
# 261  ST93Q01
# 262  ST93Q03
# 263  ST93Q04
# 264  ST93Q06
# 265  ST93Q07
# 266  ST94Q05
# 267  ST94Q06
# 268  ST94Q09
# 269  ST94Q10
# 270  ST94Q14
# 271  ST96Q01
# 272  ST96Q02
# 273  ST96Q03
# 274  ST96Q05
# 413  ANXMAT
# 431  FAILMAT
# 453  INTMAT
# 461  MATBEH
# 462  MATHEFF
# 463  MATINTFC
# 464  MATWKETH
# 475  SCMAT
# 485  USEMATH
# 500  PV1MATH
# 501  PV2MATH
# 502  PV3MATH
# 503  PV4MATH
# 504  PV5MATH
#
#                                                                                   Description
# 0    Country code 3-character
# 1    Adjudicated sub-region code 7-digit code (3-digit country code + region ID + stratum ID)
# 2    Stratum ID 7-character (cnt + region ID + original stratum ID)
# 3    OECD country
# 6    Student ID
# 7    International Grade
# 11   Gender
# 74   Subjective Norms -Friends Do Well in Mathematics
# 75   Subjective Norms -Friends Work Hard on Mathematics
# 76   Subjective Norms - Friends Enjoy Mathematics Tests
# 77   Subjective Norms - Parents Believe Studying Mathematics Is Important
# 78   Subjective Norms - Parents Believe Mathematics Is Important for Career
# 79   Subjective Norms - Parents Like Mathematics
# 88   Math Anxiety - Worry That It Will Be Difficult
# 89   Math Self-Concept - Not Good at Maths
# 90   Math Anxiety - Get Very Tense
# 91   Math Self-Concept- Get Good <Grades>
# 92   Math Anxiety - Get Very Nervous
# 93   Math Self-Concept - Learn Quickly
# 94   Math Self-Concept - One of Best Subjects
# 95   Math Anxiety - Feel Helpless
# 96   Math Self-Concept - Understand Difficult Work
# 97   Math Anxiety - Worry About Getting Poor <Grades>
# 98   Perceived Control - Can Succeed with Enough Effort
# 99   Perceived Control - Doing Well is Completely Up to Me
# 100  Perceived Control - Family Demands and Problems
# 101  Perceived Control - Different Teachers
# 102  Perceived Control - If I Wanted I Could Perform Well
# 103  Perceived Control - Perform Poorly Regardless
# 104  Attributions to Failure - Not Good at Maths Problems
# ..                                                    ...
# 259  Perceived Control - Could Perform Well if I Wanted
# 260  Perceived Control - Perform Poor Regardless
# 261  Perseverance - Give up easily
# 262  Perseverance - Put off difficult problems
# 263  Perseverance - Remain interested
# 264  Perseverance - Continue to perfection
# 265  Perseverance - Exceed expectations
# 266  Openness for Problem Solving - Can Handle a Lot of Information
# 267  Openness for Problem Solving - Quick to Understand
# 268  Openness for Problem Solving - Seek Explanations
# 269  Openness for Problem Solving - Can Link Facts
# 270  Openness for Problem Solving - Like to Solve Complex Problems
# 271  Problem Text Message - Press every button
# 272  Problem Text Message - Trace steps
# 273  Problem Text Message - Manual
# 274  Problem Text Message - Ask a friend
# 413  Mathematics Anxiety
# 431  Attributions to Failure in Mathematics
# 453  Mathematics Interest
# 461  Mathematics Behaviour
# 462  Mathematics Self-Efficacy
# 463  Mathematics Intentions
# 464  Mathematics Work Ethic
# 475  Mathematics Self-Concept
# 485  Use of ICT in Mathematic Lessons
# 500  Plausible value 1 in mathematics
# 501  Plausible value 2 in mathematics
# 502  Plausible value 3 in mathematics
# 503  Plausible value 4 in mathematics
# 504  Plausible value 5 in mathematics
#
# [91 rows x 2 columns]

# %%
### store the selected set of codes as a csv file
df_dict_clean.to_csv('pisadict2012_clean.csv', index=False)

# %%
### write the selected codes to a list and print this list
selected_codes = df_dict_clean['Code'].tolist()
print(','.join(selected_codes))
# Out:
# CNT,SUBNATIO,STRATUM,OECD,STIDSTD,ST01Q01,ST04Q01,ST35Q01,ST35Q02,ST35Q03,ST35Q04,ST35Q05,ST35Q06,ST42Q01,ST42Q02,ST42Q03,ST42Q04,ST42Q05,ST42Q06,ST42Q07,ST42Q08,ST42Q09,ST42Q10,ST43Q01,ST43Q02,ST43Q03,ST43Q04,ST43Q05,ST43Q06,ST44Q01,ST44Q03,ST44Q04,ST44Q05,ST44Q07,ST44Q08,ST46Q01,ST46Q02,ST46Q03,ST46Q04,ST46Q05,ST46Q06,ST46Q07,ST46Q08,ST46Q09,ST48Q01,ST48Q02,ST48Q03,ST48Q04,ST48Q05,ST49Q01,ST49Q02,ST49Q03,ST49Q04,ST49Q05,ST49Q06,ST49Q07,ST49Q09,ST91Q01,ST91Q02,ST91Q03,ST91Q04,ST91Q05,ST91Q06,ST93Q01,ST93Q03,ST93Q04,ST93Q06,ST93Q07,ST94Q05,ST94Q06,ST94Q09,ST94Q10,ST94Q14,ST96Q01,ST96Q02,ST96Q03,ST96Q05,ANXMAT,FAILMAT,INTMAT,MATBEH,MATHEFF,MATINTFC,MATWKETH,SCMAT,USEMATH,PV1MATH,PV2MATH,PV3MATH,PV4MATH,PV5MATH

# %% [markdown]
# ### The PISA2012 main datafile

# %%
### set up a variable that points to the csv file 
pisa = "pisa2012.csv"

# %%
### take a look at the ‘head’ of the csv file to see what the contents might look like
pd.read_csv(pisa, nrows=5)
# Out:
#    Unnamed: 0      CNT  SUBNATIO  STRATUM      OECD       NC  SCHOOLID  \
# 0  1           Albania  80000     ALB0006  Non-OECD  Albania  1
# 1  2           Albania  80000     ALB0006  Non-OECD  Albania  1
# 2  3           Albania  80000     ALB0006  Non-OECD  Albania  1
# 3  4           Albania  80000     ALB0006  Non-OECD  Albania  1
# 4  5           Albania  80000     ALB0006  Non-OECD  Albania  1
#
#    STIDSTD  ST01Q01  ST02Q01   ...     W_FSTR75  W_FSTR76 W_FSTR77 W_FSTR78  \
# 0  1        10       1         ...     13.7954   13.9235   13.1249  13.1249
# 1  2        10       1         ...     13.7954   13.9235   13.1249  13.1249
# 2  3        9        1         ...     12.7307   12.7307   12.7307  12.7307
# 3  4        9        1         ...     12.7307   12.7307   12.7307  12.7307
# 4  5        9        1         ...     12.7307   12.7307   12.7307  12.7307
#
#    W_FSTR79 W_FSTR80 WVARSTRR VAR_UNIT SENWGT_STU  VER_STU
# 0  4.3389    13.0829  19       1        0.2098     22NOV13
# 1  4.3389    13.0829  19       1        0.2098     22NOV13
# 2  4.2436    12.7307  19       1        0.1999     22NOV13
# 3  4.2436    12.7307  19       1        0.1999     22NOV13
# 4  4.2436    12.7307  19       1        0.1999     22NOV13
#
# [5 rows x 636 columns]

# %%
### create a local sqllite database
csv_dbase = create_engine('sqlite:///csv_dbase.db')

# %%
### iterate through the CSV file in chunks and store the data into sqllite

chunksize = 10000
i = 0
j = 1
for df in pd.read_csv(pisa, chunksize=chunksize, 
                      encoding='iso-8859-1', iterator=True, low_memory=False):
      df = df.rename(columns={c: c.replace(' ', '') for c in df.columns}) 
      df.index += j
      i+=1
      df.to_sql('table', csv_dbase, if_exists='append')
      j = df.index[-1] + 1

# %%
###create the cleaned dataframe that contains the 'selected_codes' only 
df_pisa = pd.read_sql('SELECT CNT,SUBNATIO,STRATUM,OECD,STIDSTD,\
                            ST01Q01,ST04Q01,\
                            ST35Q01,ST35Q02,ST35Q03,ST35Q04,ST35Q05,ST35Q06,\
                            ST42Q01,ST42Q02,ST42Q03,ST42Q04,ST42Q05,\
                            ST42Q06,ST42Q07,ST42Q08,ST42Q09,ST42Q10,\
                            ST43Q01,ST43Q02,ST43Q03,ST43Q04,ST43Q05,ST43Q06,\
                            ST44Q01,ST44Q03,ST44Q04,ST44Q05,ST44Q07,ST44Q08,\
                            ST46Q01,ST46Q02,ST46Q03,ST46Q04,ST46Q05,ST46Q06,\
                            ST46Q07,ST46Q08,ST46Q09,\
                            ST48Q01,ST48Q02,ST48Q03,ST48Q04,ST48Q05,\
                            ST49Q01,ST49Q02,ST49Q03,ST49Q04,ST49Q05, \
                            ST49Q06,ST49Q07,ST49Q09,\
                            ST91Q01,ST91Q02,ST91Q03,ST91Q04,ST91Q05,ST91Q06,\
                            ST93Q01,ST93Q03,ST93Q04,ST93Q06,ST93Q07,\
                            ST94Q05,ST94Q06,ST94Q09,ST94Q10, ST94Q14,\
                            ST96Q01,ST96Q02,ST96Q03,ST96Q05,\
                            ANXMAT,FAILMAT,INTMAT,MATBEH,MATHEFF,\
                            MATINTFC,MATWKETH,SCMAT,USEMATH,\
                            PV1MATH,PV2MATH,PV3MATH,PV4MATH,PV5MATH \
                            FROM "table"', csv_dbase)

# %%
df_pisa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485490 entries, 0 to 485489
# Data columns (total 91 columns):
# CNT         485490 non-null object
# SUBNATIO    485490 non-null int64
# STRATUM     485490 non-null object
# OECD        485490 non-null object
# STIDSTD     485490 non-null int64
# ST01Q01     485490 non-null int64
# ST04Q01     485490 non-null object
# ST35Q01     315860 non-null object
# ST35Q02     315315 non-null object
# ST35Q03     314873 non-null object
# ST35Q04     315160 non-null object
# ST35Q05     314843 non-null object
# ST35Q06     313389 non-null object
# ST42Q01     313855 non-null object
# ST42Q02     313502 non-null object
# ST42Q03     312176 non-null object
# ST42Q04     311980 non-null object
# ST42Q05     312624 non-null object
# ST42Q06     312327 non-null object
# ST42Q07     312583 non-null object
# ST42Q08     312456 non-null object
# ST42Q09     312223 non-null object
# ST42Q10     312853 non-null object
# ST43Q01     314971 non-null object
# ST43Q02     314182 non-null object
# ST43Q03     313494 non-null object
# ST43Q04     313420 non-null object
# ST43Q05     313228 non-null object
# ST43Q06     313470 non-null object
# ST44Q01     314119 non-null object
# ST44Q03     313405 non-null object
# ST44Q04     312645 non-null object
# ST44Q05     312996 non-null object
# ST44Q07     312970 non-null object
# ST44Q08     313374 non-null object
# ST46Q01     313898 non-null object
# ST46Q02     313567 non-null object
# ST46Q03     312994 non-null object
# ST46Q04     312997 non-null object
# ST46Q05     313043 non-null object
# ST46Q06     312900 non-null object
# ST46Q07     312854 non-null object
# ST46Q08     312989 non-null object
# ST46Q09     313040 non-null object
# ST48Q01     294410 non-null object
# ST48Q02     289827 non-null object
# ST48Q03     298479 non-null object
# ST48Q04     267716 non-null object
# ST48Q05     287992 non-null object
# ST49Q01     313495 non-null object
# ST49Q02     313025 non-null object
# ST49Q03     312168 non-null object
# ST49Q04     312378 non-null object
# ST49Q05     312582 non-null object
# ST49Q06     312571 non-null object
# ST49Q07     312425 non-null object
# ST49Q09     312752 non-null object
# ST91Q01     311430 non-null object
# ST91Q02     310396 non-null object
# ST91Q03     309826 non-null object
# ST91Q04     309398 non-null object
# ST91Q05     309610 non-null object
# ST91Q06     309656 non-null object
# ST93Q01     312856 non-null object
# ST93Q03     312140 non-null object
# ST93Q04     311311 non-null object
# ST93Q06     312270 non-null object
# ST93Q07     312259 non-null object
# ST94Q05     312404 non-null object
# ST94Q06     312185 non-null object
# ST94Q09     311413 non-null object
# ST94Q10     311747 non-null object
# ST94Q14     312001 non-null object
# ST96Q01     311381 non-null object
# ST96Q02     311460 non-null object
# ST96Q03     311078 non-null object
# ST96Q05     311319 non-null object
# ANXMAT      314764 non-null float64
# FAILMAT     314448 non-null float64
# INTMAT      316708 non-null float64
# MATBEH      313847 non-null float64
# MATHEFF     315948 non-null float64
# MATINTFC    301360 non-null float64
# MATWKETH    314501 non-null float64
# SCMAT       314607 non-null float64
# USEMATH     290260 non-null float64
# PV1MATH     485490 non-null float64
# PV2MATH     485490 non-null float64
# PV3MATH     485490 non-null float64
# PV4MATH     485490 non-null float64
# PV5MATH     485490 non-null float64
# dtypes: float64(14), int64(3), object(74)
# memory usage: 337.1+ MB

# %%
### list of participating countries
set(df_pisa.CNT)
# Out:
# {'Albania',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'China-Shanghai',
#  'Chinese Taipei',
#  'Colombia',
#  'Connecticut (USA)',
#  'Costa Rica',
#  'Croatia',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'Florida (USA)',
#  'France',
#  'Germany',
#  'Greece',
#  'Hong Kong-China',
#  'Hungary',
#  'Iceland',
#  'Indonesia',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Korea',
#  'Latvia',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Macao-China',
#  'Malaysia',
#  'Massachusetts (USA)',
#  'Mexico',
#  'Montenegro',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'Perm(Russian Federation)',
#  'Peru',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Serbia',
#  'Singapore',
#  'Slovak Republic',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Thailand',
#  'Tunisia',
#  'Turkey',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States of America',
#  'Uruguay',
#  'Vietnam'}

# %%
### replace 'Florida (USA)', 'Connecticut (USA)' and 'Massacusets (USA)' 
### with 'United States of America
df_pisa['CNT'].replace('Connecticut (USA)', 'United States of America', inplace=True)
df_pisa['CNT'].replace('Florida (USA)', 'United States of America', inplace=True)
df_pisa['CNT'].replace('Massachusetts (USA)', 'United States of America', inplace=True)

# %%
### replace 'Perm(Russian Federation)' with 'Russian Federation'
df_pisa['CNT'].replace('Perm(Russian Federation)', 'Russian Federation', inplace=True)

# %%
### combine 'China-Shangai', 'Hong King - China', 'Macao-China'  as 'China'
df_pisa['CNT'].replace('China-Shanghai', 'China', inplace=True)
df_pisa['CNT'].replace('Hong Kong-China', 'China', inplace=True)
df_pisa['CNT'].replace('Macao-China', 'China', inplace=True)

# %%
### the updated list of countries
set(df_pisa.CNT)
# Out:
# {'Albania',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'China',
#  'Chinese Taipei',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Indonesia',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Korea',
#  'Latvia',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Malaysia',
#  'Mexico',
#  'Montenegro',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'Peru',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Serbia',
#  'Singapore',
#  'Slovak Republic',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Thailand',
#  'Tunisia',
#  'Turkey',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States of America',
#  'Uruguay',
#  'Vietnam'}

# %%
### the number of participating countries, as defined here
len(set(df_pisa.CNT))
# Out:
# 62

# %%
### review the cleaned dataframe
df_pisa.head(4)
# Out:
#        CNT  SUBNATIO  STRATUM      OECD  STIDSTD  ST01Q01 ST04Q01  \
# 0  Albania  80000     ALB0006  Non-OECD  1        10       Female
# 1  Albania  80000     ALB0006  Non-OECD  2        10       Female
# 2  Albania  80000     ALB0006  Non-OECD  3        9        Female
# 3  Albania  80000     ALB0006  Non-OECD  4        9        Female
#
#           ST35Q01         ST35Q02   ST35Q03    ...    MATHEFF MATINTFC  \
# 0  Disagree        Agree           Disagree    ...    -0.77   -0.7332
# 1  Strongly agree  Strongly agree  Disagree    ...     0.34   -0.2514
# 2  Strongly agree  Strongly agree  Agree       ...     0.34   -0.2514
# 3  None            None            None        ...    NaN     NaN
#
#   MATWKETH SCMAT USEMATH   PV1MATH   PV2MATH   PV3MATH   PV4MATH   PV5MATH
# 0  0.2882   0.41 NaN      406.8469  376.4683  344.5319  321.1637  381.9209
# 1  0.6490  NaN   NaN      486.1427  464.3325  453.4273  472.9008  476.0165
# 2  2.0389  NaN   NaN      533.2684  481.0796  489.6479  490.4269  533.2684
# 3 NaN       0.18 NaN      412.2215  498.6836  415.3373  466.7472  454.2842
#
# [4 rows x 91 columns]

# %%
### get an overall description of the numerical data
df_pisa.describe()
# Out:
#            SUBNATIO        STIDSTD        ST01Q01         ANXMAT  \
# count  4.854900e+05  485490.000000  485490.000000  314764.000000
# mean   4.315457e+06  6134.066201    9.813323       0.152647
# std    2.524434e+06  6733.144944    3.734726       0.955031
# min    8.000000e+04  1.000000       7.000000      -2.370000
# 25%    2.030000e+06  1811.000000    9.000000      -0.470000
# 50%    4.100000e+06  3740.000000    10.000000      0.060000
# 75%    6.880000e+06  7456.000000    10.000000      0.790000
# max    8.580000e+06  33806.000000   96.000000      2.550000
#
#              FAILMAT         INTMAT         MATBEH        MATHEFF  \
# count  314448.000000  316708.000000  313847.000000  315948.000000
# mean  -0.013110       0.212424       0.241209      -0.046626
# std    1.029037       1.004716       1.054971       0.973588
# min   -3.766600      -1.780000      -2.140200      -3.750000
# 25%   -0.530000      -0.340000      -0.456700      -0.630000
# 50%   -0.076000       0.300000       0.217100      -0.180000
# 75%    0.640000       0.910000       0.811000       0.540000
# max    3.906700       2.290000       4.424900       2.270000
#
#             MATINTFC       MATWKETH          SCMAT        USEMATH  \
# count  301360.000000  314501.000000  314607.000000  290260.000000
# mean  -0.012782       0.135775       0.035656       0.067043
# std    0.997417       1.009700       0.955625       1.031781
# min   -1.532900      -3.450300      -2.180000      -0.774900
# 25%   -0.733200      -0.401700      -0.520000      -0.774900
# 50%   -0.138100       0.109900      -0.060000      -0.774900
# 75%    0.658400       0.649000       0.650000       0.869500
# max    1.456500       2.716700       2.260000       2.801100
#
#              PV1MATH        PV2MATH        PV3MATH        PV4MATH  \
# count  485490.000000  485490.000000  485490.000000  485490.000000
# mean   469.621653     469.648358     469.648930     469.641832
# std    103.265391     103.382077     103.407631     103.392286
# min    19.792800      6.473000       42.226200      24.622200
# 25%    395.318600     395.318600     395.240700     395.396500
# 50%    466.201900     466.124000     466.201900     466.279800
# 75%    541.057800     541.447300     541.291500     541.447300
# max    962.229300     957.010400     935.745400     943.456900
#
#              PV5MATH
# count  485490.000000
# mean   469.695396
# std    103.419170
# min    37.085200
# 25%    395.240700
# 50%    466.435600
# 75%    541.447300
# max    907.625800

# %%
### store the cleaned dataframe as a csv file
df_pisa.to_csv('pisa2012_clean.csv', index=False)
